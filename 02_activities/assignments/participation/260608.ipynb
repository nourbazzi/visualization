# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import requests
import scipy
import PIL
import requests

# %%
np.random.seed(613)
x = np.arange(50)
y1 = np.random.randint(0, 100, 50)
y2 = np.random.randint(0, 100, 50)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1)
ax.plot(x,y2)
fig.show()
# Out:
# C:\Users\nourb\AppData\Local\Temp\ipykernel_21300\3608551665.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, label = "Person 1" )
ax.plot(x,y2, label = "Person 2" )
ax.legend(loc='lower right')
fig.show()
# Out:
# C:\Users\nourb\AppData\Local\Temp\ipykernel_21300\133585955.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, label = "Person 1")
ax.plot(x,y2, label = "Person 2")
ax.legend(loc='lower right', 
          frameon = True, #add frame around the legend 
          fontsize = 12, #change font size 
          ncol = 2, #specify number of columns 
          shadow = True )
fig.show()
# Out:
# C:\Users\nourb\AppData\Local\Temp\ipykernel_21300\2107359021.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, label = "Person 1")
ax.plot(x,y2, label = "Person 2")
ax.legend(loc='upper left', 
          bbox_to_anchor=(1, 1))
fig.show()
# Out:
# C:\Users\nourb\AppData\Local\Temp\ipykernel_21300\2486145503.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.text(10, 95, "This value is important!",
        ha='center', #alignment of text
        color='red', #font color
        size=20) #font size
fig.show()
# Out:
# C:\Users\nourb\AppData\Local\Temp\ipykernel_21300\646996378.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots()
ax.axis([0, 10, 0, 10])
# Out:
# (np.float64(0.0), np.float64(10.0), np.float64(0.0), np.float64(10.0))

# %%
ax.text(1, 5, ". Data:(1, 5)", transform=ax.transData ) #. Data:(1, 5) means the text will be placed at the coordinates (1, 5) in data space
ax.text(0.5, 0.1, ". Axes:(0.5, 0.1)", transform=ax.transAxes ) #. Axes:(0.5, 0.1) means the text will be placed at the coordinates (0.5, 0.1) in axes space, where (0, 0) is the bottom-left corner and (1, 1) is the top-right corner of the a
ax.text(0.2, 0.2, ". Figure:(0.2, 0.2)", transform=fig.transFigure ) #. Figure:(0.2, 0.2) means the text will be placed at the coordinates (0.2, 0.2) in figure space
# Out:
# Text(0.2, 0.2, '. Figure:(0.2, 0.2)')

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.annotate('This is important!', xy=(10, 95), xytext=(20, 94), 
            arrowprops=dict(facecolor='black'))
fig.show()
# Out:
# C:\Users\nourb\AppData\Local\Temp\ipykernel_21300\1534677993.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.annotate('This is important!', 
            xy=(10, 95), 
            xytext=(20, 94), 
            arrowprops = dict(arrowstyle = "wedge", 
                              color = "hotpink"))
fig.show()
# Out:
# C:\Users\nourb\AppData\Local\Temp\ipykernel_21300\4050025883.py:10: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_formatter(plt.NullFormatter())

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.xaxis.set_major_locator(plt.MaxNLocator(3))

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.xaxis.set_major_locator(plt.MultipleLocator(5))

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
plt.xticks(rotation=45, ha='right')
# Out:
# (array([-10.,   0.,  10.,  20.,  30.,  40.,  50.,  60.]),
#  [Text(-10.0, 0, '−10'),
#   Text(0.0, 0, '0'),
#   Text(10.0, 0, '10'),
#   Text(20.0, 0, '20'),
#   Text(30.0, 0, '30'),
#   Text(40.0, 0, '40'),
#   Text(50.0, 0, '50'),
#   Text(60.0, 0, '60')])

# %%
font1 = {' family':'serif','color':'indigo'}
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
plt.xlabel('Shiny New X Axis!', fontsize = 18, fontdict = font1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 6
#       4 ax.scatter(x,y2, label = "Person 2")
#       5 ax.legend(loc='lower right')
# ----> 6 plt.xlabel('Shiny New X Axis!', fontsize = 18, fontdict = font1)
#
# File c:\Users\nourb\OneDrive - University of Toronto\Desktop\DSI\visualization\visualization-env\Lib\site-packages\matplotlib\pyplot.py:4407, in xlabel(xlabel, fontdict, labelpad, loc, **kwargs)
#    4398 @_copy_docstring_and_deprecators(Axes.set_xlabel)
#    4399 def xlabel(
#    4400     xlabel: str,
#    (...)   4405     **kwargs,
#    4406 ) -> Text:
# -> 4407     return gca().set_xlabel(
#    4408         xlabel, fontdict=fontdict, labelpad=labelpad, loc=loc, **kwargs
#    4409     )
#
# File c:\Users\nourb\OneDrive - University of Toronto\Desktop\DSI\visualization\visualization-env\Lib\site-packages\matplotlib\axes\_base.py:3645, in _AxesBase.set_xlabel(self, xlabel, fontdict, labelpad, loc, **kwargs)
#    3638     x = {
#    3639         'left': 0,
#    3640         'center': 0.5,
#    3641         'right': 1,
#    3642     }[loc]
#    3643     kwargs.update(x=x, horizontalalignment=loc)
# -> 3645 return self.xaxis.set_label_text(xlabel, fontdict, **kwargs)
#
# File c:\Users\nourb\OneDrive - University of Toronto\Desktop\DSI\visualization\visualization-env\Lib\site-packages\matplotlib\axis.py:1901, in Axis.set_label_text(self, label, fontdict, **kwargs)
#    1899 self.label.set_text(label)
#    1900 if fontdict is not None:
# -> 1901     self.label.update(fontdict)
#    1902 self.label.update(kwargs)
#    1903 self.stale = True
#
# File c:\Users\nourb\OneDrive - University of Toronto\Desktop\DSI\visualization\visualization-env\Lib\site-packages\matplotlib\text.py:205, in Text.update(self, kwargs)
#     203 # Update bbox last, as it depends on font properties.
#     204 bbox = kwargs.pop("bbox", sentinel)
# --> 205 ret.extend(super().update(kwargs))
#     206 if bbox is not sentinel:
#     207     ret.append(self.set_bbox(bbox))
#
# File c:\Users\nourb\OneDrive - University of Toronto\Desktop\DSI\visualization\visualization-env\Lib\site-packages\matplotlib\artist.py:1223, in Artist.update(self, props)
#    1215 def update(self, props):
#    1216     """
#    1217     Update this artist's properties from the dict *props*.
#    1218
#    (...)   1221     props : dict
#    1222     """
# -> 1223     return self._update_props(
#    1224         props, "{cls.__name__!r} object has no property {prop_name!r}")
#
# File c:\Users\nourb\OneDrive - University of Toronto\Desktop\DSI\visualization\visualization-env\Lib\site-packages\matplotlib\artist.py:1206, in Artist._update_props(self, props, errfmt)
#    1204             func = getattr(self, f"set_{k}", None)
#    1205             if not callable(func):
# -> 1206                 raise AttributeError(
#    1207                     errfmt.format(cls=type(self), prop_name=k),
#    1208                     name=k)
#    1209             ret.append(func(v))
#    1210 if ret:
#
# AttributeError: 'Text' object has no property ' family'

# %%
plt.style.use('fivethirtyeight')

np.random.seed(613)
x = np.arange(50)
y1 = np.random.randint(0, 100,50)
y2 = np.random.randint(0, 100,50)
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1)
ax.plot(x,y2)
fig.show()
# Out:
# C:\Users\nourb\AppData\Local\Temp\ipykernel_21300\1039124237.py:10: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']
